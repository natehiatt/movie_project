# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import sqlite3

# %%
bom = pd.read_csv('../data/bom.movie_gross.csv.gz')

# %%
bom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
bom
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
reviews = pd.read_csv('../data/rt.reviews.tsv.gz', sep='\t', encoding='latin-1')

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
reviews
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
movie_info = pd.read_csv('../data/rt.movie_info.tsv.gz', sep='\t', encoding='latin-1')

# %%
movie_info
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
budgets = pd.read_csv('../data/tn.movie_budgets.csv.gz')

# %%
budgets
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
movies = pd.read_csv('../data/tmdb.movies.csv.gz')

# %%
movies
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
con = sqlite3.connect('../data/im.db')

# %%
 pd.read_sql("""

SELECT DISTINCT person_id
       
FROM writers




""", con)
# Out:
#          person_id
# 0        nm0899854
# 1        nm0175726
# 2        nm1802864
# 3        nm1940585
# 4        nm0310087
# ...            ...
# 122571  nm10122247
# 122572  nm10122246
# 122573  nm10122357
# 122574   nm6711477
# 122575   nm8352242
#
# [122576 rows x 1 columns]

# %%
 pd.read_sql("""

SELECT *
       
FROM movie_ratings

WHERE numvotes >= 100

ORDER BY numvotes DESC


""", con)
# Out:
#         movie_id  averagerating  numvotes
# 0      tt1375666            8.8   1841066
# 1      tt1345836            8.4   1387769
# 2      tt0816692            8.6   1299334
# 3      tt1853728            8.4   1211405
# 4      tt0848228            8.1   1183655
# ...          ...            ...       ...
# 28748  tt9270416            4.7       100
# 28749  tt4624138            6.0       100
# 28750  tt2270168            6.4       100
# 28751  tt7830428            5.1       100
# 28752  tt7925504            6.6       100
#
# [28753 rows x 3 columns]

# %%
 pd.read_sql("""

SELECT DISTINCT movie_id
       
FROM movie_akas

WHERE attributes LIKE '%3-D%'



""", con)
# Out:
#       movie_id
# 0    tt0369610
# 1    tt0401729
# 2    tt1869504
# 3    tt2215719
# 4    tt0816711
# ..         ...
# 241  tt5007458
# 242  tt4410000
# 243  tt3829266
# 244  tt4633694
# 245  tt6139732
#
# [246 rows x 1 columns]

# %%
 pd.read_sql("""

SELECT DISTINCT movie_id
       
FROM movie_akas

WHERE attributes LIKE '%3-D%'



""", con)
# Out:
#       movie_id
# 0    tt0369610
# 1    tt0401729
# 2    tt1869504
# 3    tt2215719
# 4    tt0816711
# ..         ...
# 241  tt5007458
# 242  tt4410000
# 243  tt3829266
# 244  tt4633694
# 245  tt6139732
#
# [246 rows x 1 columns]

# %%
 pd.read_sql("""

SELECT region, COUNT(region)
       
FROM movie_akas

GROUP BY region

ORDER BY COUNT(region) DESC




""", con)
# Out:
#     region  COUNT(region)
# 0       US          51490
# 1      XWW          18467
# 2       RU          13817
# 3       DE          11634
# 4       FR          10990
# ..     ...            ...
# 209   CSHH              1
# 210     CF              1
# 211   BUMM              1
# 212     AI              1
# 213   None              0
#
# [214 rows x 2 columns]

# %%
 pd.read_sql("""

SELECT language, COUNT(language)
       
FROM movie_akas

GROUP BY language

ORDER BY COUNT(language) DESC




""", con)
# Out:
#    language  COUNT(language)
# 0        en            22895
# 1        tr             3847
# 2        bg             3609
# 3        fr             3576
# 4        he             2680
# ..      ...              ...
# 72       gd                1
# 73      fro                1
# 74       et                1
# 75       cy                1
# 76     None                0
#
# [77 rows x 2 columns]

# %%
 moviebasics = pd.read_sql("""

SELECT *
       
FROM movie_basics





""", con)

# %%
movies_data = movies.rename(columns={"title": 'primary_title'})

moviesdf = pd.merge(moviebasics, movies_data, on = 'primary_title')

# %%
moviesdf.describe()
# Out:
#          start_year  runtime_minutes   Unnamed: 0             id  \
# count  23612.000000     21750.000000  23612.00000   23612.000000
# mean    2014.341521        92.190161  13517.60681  288863.416822
# std        2.730943        25.702140   7500.52069  148883.982125
# min     2010.000000         1.000000      0.00000     189.000000
# 25%     2012.000000        83.000000   7162.00000  156881.000000
# 50%     2014.000000        91.000000  13820.50000  302790.000000
# 75%     2016.000000       102.000000  20080.00000  408544.000000
# max     2115.000000      1834.000000  26516.00000  608444.000000
#
#          popularity  vote_average    vote_count
# count  23612.000000  23612.000000  23612.000000
# mean       3.817933      5.809991    270.412036
# std        4.810936      1.717266   1107.519115
# min        0.600000      0.000000      1.000000
# 25%        0.656000      5.000000      2.000000
# 50%        1.785000      6.000000      8.000000
# ...

# %%
popularity_budget_df = pd.merge(budgets, movies, on = 'id')

# %%
popularity_budget_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 344 entries, 0 to 343
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 344 non-null    int64
#  1   release_date_x     344 non-null    object
#  2   movie              344 non-null    object
#  3   production_budget  344 non-null    object
#  4   domestic_gross     344 non-null    object
#  5   worldwide_gross    344 non-null    object
#  6   Unnamed: 0         344 non-null    int64
#  7   genre_ids          344 non-null    object
#  8   original_language  344 non-null    object
#  9   original_title     344 non-null    object
#  10  popularity         344 non-null    float64
#  11  release_date_y     344 non-null    object
#  12  title              344 non-null    object
#  13  vote_average       344 non-null    float64
#  14  vote_count         344 non-null    int64
# dtypes: float64(2), int64(3), object(10)
# ...

# %%
popularity_budget_df['worldwide_gross'] = popularity_budget_df['worldwide_gross'].apply(str).str.replace('$', '')
popularity_budget_df['worldwide_gross'] = popularity_budget_df['worldwide_gross'].apply(str).str.replace(',', '').astype(float)
popularity_budget_df
# Out:
#      id release_date_x                                  movie  \
# 0    27    May 4, 2012                           The Avengers
# 1    27   May 21, 2010                    Shrek Forever After
# 2    27   Dec 25, 2015                           The Revenant
# 3    27   Dec 17, 2004                            The Aviator
# 4    27   Dec 18, 2002  The Lord of the Rings: The Two Towers
# ..   ..            ...                                    ...
# 339  97   May 15, 2015                              Childless
# 340  97    Apr 7, 1933                              King Kong
# 341  97   Aug 11, 2006         Conversations with Other Women
# 342  97   Apr 11, 2014                           Jesus People
# 343  97   Mar 25, 2015                            Open Secret
#
#     production_budget domestic_gross  worldwide_gross  Unnamed: 0  \
# 0        $225,000,000   $623,279,547     1.517936e+09         117
# 1        $165,000,000   $238,736,787     7.562447e+08         117
# ...

# %%
popularity_budget_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 344 entries, 0 to 343
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 344 non-null    int64
#  1   release_date_x     344 non-null    object
#  2   movie              344 non-null    object
#  3   production_budget  344 non-null    object
#  4   domestic_gross     344 non-null    object
#  5   worldwide_gross    344 non-null    float64
#  6   Unnamed: 0         344 non-null    int64
#  7   genre_ids          344 non-null    object
#  8   original_language  344 non-null    object
#  9   original_title     344 non-null    object
#  10  popularity         344 non-null    float64
#  11  release_date_y     344 non-null    object
#  12  title              344 non-null    object
#  13  vote_average       344 non-null    float64
#  14  vote_count         344 non-null    int64
# dtypes: float64(3), int64(3), object(9)
# ...

# %%
popularity_budget_df.groupby('worldwide_gross')['popularity']

# %%
 movieakas = pd.read_sql("""

SELECT *
       
FROM movie_akas





""", con)

# %%
movieakas = movieakas.rename(columns={"title": 'movie'})

# %%
movieakas_budgets_df = pd.merge(movieakas, budgets, on = 'movie')

movieakas_budgets_df
# Out:
#         movie_id  ordering           movie region language        types  \
# 0      tt0369610        14  Jurassic World     FR     None  imdbDisplay
# 1      tt0369610        15  Jurassic World     GR     None  imdbDisplay
# 2      tt0369610        16  Jurassic World     IT     None  imdbDisplay
# 3      tt0369610        20  Jurassic World     SE     None  imdbDisplay
# 4      tt0369610        29  Jurassic World     US     None         None
# ...          ...       ...             ...    ...      ...          ...
# 10603  tt5462602         3    The Big Sick   None     None     original
# 10604  tt5462602         8    The Big Sick     FR     None  imdbDisplay
# 10605  tt5649108         2   Thoroughbreds     US     None         None
# 10606  tt5649108         9   Thoroughbreds   None     None     original
# 10607  tt6198946        13        Impostor     PL     None  imdbDisplay
#
#       attributes  is_original_title  id  release_date production_budget  \
# ...

# %%
movieakas_budgets_df = movieakas_budgets_df.dropna(subset=['attributes'])
threed_budgets_df= movieakas_budgets_df[movieakas_budgets_df['attributes'].str.contains('3-D')]
no_threed_budgets_df= movieakas_budgets_df[movieakas_budgets_df['attributes'].str.contains('3-D')==False]

# %%
threed_budgets_df
# Out:
#         movie_id  ordering                           movie region language  \
# 291    tt0831387         8                        Godzilla     UY     None
# 292    tt0831387         8                        Godzilla     UY     None
# 736    tt1860353        23                           Turbo     UY     None
# 1376   tt1679335        18                          Trolls     UY     None
# 1508   tt1365519        12                     Tomb Raider     UY     None
# 1646   tt2293640        25                         Minions     UY     None
# 2564   tt2380307        35                            Coco     UY     None
# 2685   tt1702443         3  Justin Bieber: Never Say Never     UY     None
# 2890   tt0435761        20                     Toy Story 3     UY     None
# 3419   tt0837562        19              Hotel Transylvania     UY     None
# 3775   tt0448115         2                         Shazam!     UY     None
# ...

# %%
no_threed_popularity_df
# Out:
#         movie_id  ordering                title region language types  \
# 37     tt1014759         6                Alice     US     None  None
# 43     tt6089700         4                Alice   None     None  None
# 77     tt4886070         1           Motherland     US     None  None
# 78     tt4886070         1           Motherland     US     None  None
# 79     tt4886070         1           Motherland     US     None  None
# ...          ...       ...                  ...    ...      ...   ...
# 46745  tt6769280         9      Time After Time     GB     None  None
# 46779  tt3262342        14       Loving Vincent     UY     None  None
# 46780  tt3262342        14       Loving Vincent     UY     None  None
# 46799  tt3332282         3  Dawning of the Dead     US     None  None
# 46817  tt3862762         1   No Beast So Fierce     US     None  None
#
#                        attributes  is_original_title  Unnamed: 0  \
# ...

# %%
threed_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 291 to 10407
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           29 non-null     object
#  1   ordering           29 non-null     int64
#  2   movie              29 non-null     object
#  3   region             29 non-null     object
#  4   language           0 non-null      object
#  5   types              0 non-null      object
#  6   attributes         29 non-null     object
#  7   is_original_title  29 non-null     float64
#  8   id                 29 non-null     int64
#  9   release_date       29 non-null     object
#  10  production_budget  29 non-null     object
#  11  domestic_gross     29 non-null     object
#  12  worldwide_gross    29 non-null     object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 3.2+ KB

# %%
threed_budgets_df['worldwide_gross'] = threed_budgets_df['worldwide_gross'].apply(str).str.replace('$', '')
threed_budgets_df['worldwide_gross'] = threed_budgets_df['worldwide_gross'].apply(str).str.replace(',', '').astype(int)
threed_budgets_df
# Out:
# <ipython-input-140-400827144f98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   threed_budgets_df['worldwide_gross'] = threed_budgets_df['worldwide_gross'].apply(str).str.replace('$', '')
# <ipython-input-140-400827144f98>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   threed_budgets_df['worldwide_gross'] = threed_budgets_df['worldwide_gross'].apply(str).str.replace(',', '').astype(int)
#         movie_id  ordering                           movie region language  \
# ...

# %%
threed_budgets_df['domestic_gross'] = threed_budgets_df['domestic_gross'].apply(str).str.replace('$', '')
threed_budgets_df['domestic_gross'] = threed_budgets_df['domestic_gross'].apply(str).str.replace(',', '').astype(int)
threed_budgets_df
# Out:
# <ipython-input-141-0db94ec7975b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   threed_budgets_df['domestic_gross'] = threed_budgets_df['domestic_gross'].apply(str).str.replace('$', '')
# <ipython-input-141-0db94ec7975b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   threed_budgets_df['domestic_gross'] = threed_budgets_df['domestic_gross'].apply(str).str.replace(',', '').astype(int)
#         movie_id  ordering                           movie region language  \
# ...

# %%
threed_budgets_df['production_budget'] = threed_budgets_df['production_budget'].apply(str).str.replace('$', '')
threed_budgets_df['production_budget'] = threed_budgets_df['production_budget'].apply(str).str.replace(',', '').astype(int)
threed_budgets_df
# Out:
# <ipython-input-142-423506a683cf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   threed_budgets_df['production_budget'] = threed_budgets_df['production_budget'].apply(str).str.replace('$', '')
# <ipython-input-142-423506a683cf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   threed_budgets_df['production_budget'] = threed_budgets_df['production_budget'].apply(str).str.replace(',', '').astype(int)
#         movie_id  ordering                           movie region language  \
# ...

# %%
no_threed_budgets_df['worldwide_gross'] = no_threed_budgets_df['worldwide_gross'].apply(str).str.replace('$', '')
no_threed_budgets_df['worldwide_gross'] = no_threed_budgets_df['worldwide_gross'].apply(str).str.replace(',', '').astype(int)
no_threed_budgets_df
# Out:
# <ipython-input-143-943d2f182c42>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_threed_budgets_df['worldwide_gross'] = no_threed_budgets_df['worldwide_gross'].apply(str).str.replace('$', '')
# <ipython-input-143-943d2f182c42>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_threed_budgets_df['worldwide_gross'] = no_threed_budgets_df['worldwide_gross'].apply(str).str.replace(',', '').astype(int)
#         movie_id  ordering                                      movie region  \
# ...

# %%
no_threed_budgets_df['domestic_gross'] = no_threed_budgets_df['domestic_gross'].apply(str).str.replace('$', '')
no_threed_budgets_df['domestic_gross'] = no_threed_budgets_df['domestic_gross'].apply(str).str.replace(',', '').astype(int)
no_threed_budgets_df
# Out:
# <ipython-input-144-e118dc0590a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_threed_budgets_df['domestic_gross'] = no_threed_budgets_df['domestic_gross'].apply(str).str.replace('$', '')
# <ipython-input-144-e118dc0590a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_threed_budgets_df['domestic_gross'] = no_threed_budgets_df['domestic_gross'].apply(str).str.replace(',', '').astype(int)
#         movie_id  ordering                                      movie region  \
# ...

# %%
no_threed_budgets_df['production_budget'] = no_threed_budgets_df['production_budget'].apply(str).str.replace('$', '')
no_threed_budgets_df['production_budget'] = no_threed_budgets_df['production_budget'].apply(str).str.replace(',', '').astype(int)
no_threed_budgets_df
# Out:
# <ipython-input-145-d22b8da58e4f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_threed_budgets_df['production_budget'] = no_threed_budgets_df['production_budget'].apply(str).str.replace('$', '')
# <ipython-input-145-d22b8da58e4f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_threed_budgets_df['production_budget'] = no_threed_budgets_df['production_budget'].apply(str).str.replace(',', '').astype(int)
# ...

# %%
threed_budgets_df['worldwide_ROI'] = ((threed_budgets_df['worldwide_gross'] - threed_budgets_df['production_budget']) / threed_budgets_df['production_budget']) * 100
# Out:
# <ipython-input-190-90e0b6a951dd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   threed_budgets_df['worldwide_ROI'] = ((threed_budgets_df['worldwide_gross'] - threed_budgets_df['production_budget']) / threed_budgets_df['production_budget']) * 100

# %%
no_threed_budgets_df['worldwide_ROI'] = ((no_threed_budgets_df['worldwide_gross'] - no_threed_budgets_df['production_budget']) / no_threed_budgets_df['production_budget']) * 100
# Out:
# <ipython-input-191-bfba408af553>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_threed_budgets_df['worldwide_ROI'] = ((no_threed_budgets_df['worldwide_gross'] - no_threed_budgets_df['production_budget']) / no_threed_budgets_df['production_budget']) * 100

# %%
threed_budget_mean = threed_budgets_df['production_budget'].mean()

# %%
no_threed_budget_mean = no_threed_budgets_df['production_budget'].mean()

# %%
threed_wwgross_mean = threed_budgets_df['worldwide_gross'].mean()

# %%
no_threed_wwgross_mean = no_threed_budgets_df['worldwide_gross'].mean()

# %%
threed_ww_roi = ((threed_wwgross_mean - threed_budget_mean) / threed_budget_mean)

# %%
no_threed_ww_roi = ((no_threed_wwgross_mean - no_threed_budget_mean) / no_threed_budget_mean)

# %%
threed_ww_roi
# Out:
# 2.9276869609756098

# %%
no_threed_ww_roi
# Out:
# 2.5075673930563234

# %%
tstat, pvalue = stats.ttest_ind(threed_budgets_df['worldwide_ROI'], no_threed_budgets_df['worldwide_ROI'], equal_var = False)

# %%
pvalue
# Out:
# 0.15864711962189187
